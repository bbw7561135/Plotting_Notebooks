# %%
pwd
# Out:
# u'/home/amao'

# %%
cd /home/amao/seaborn-data/
# Out:
# /home/amao/seaborn-data

# %%
pwd
# Out:
# u'/home/amao/seaborn-data'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyPLUTO as pp
import seaborn as sns
# %matplotlib inline
# Out:
# /home/amao/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pp.curdir()
# Out:
# '/home/amao/seaborn-data/'

# %%
D = pp.pload(1) # Loading the data into a pload object D.
#grid.out dbl.out should contain
# Out:
# Reading Data file : /home/amao/seaborn-data/data.0001.dbl

# %%
plt.figure(figsize=(8,5))
plt.plot(D.x1,D.rho,color='r',linewidth=1.2,linestyle="-",label="density")
plt.plot(D.x1,D.prs,color='k',linewidth=1.2,linestyle="--",label="pressure")
plt.plot(D.x1,D.vx1,color='g',linewidth=1.2,linestyle="-.",label="velocity_x1")         
plt.xlabel(r'x')
plt.ylabel(r'$\rho$ [red], P [black], $V_{\rm x}$ [green]')
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend()
plt.savefig('sod_1.pdf',dpi=80)

# %%
plt.figure(figsize=(16,10))
# 创建在1x1的位置创建一个subplot
plt.subplot(221)
plt.plot(D.x1,D.rho,color='r',linewidth=1.2,linestyle="-",label="density")
plt.xlabel(r'x')
plt.ylabel(r'$\rho$ [red], P [black], $V_{\rm x}$ [green]')
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend()
plt.subplot(222)
plt.plot(D.x1,D.prs,color='k',linewidth=1.2,linestyle="--",label="pressure")
plt.xlabel(r'x')
plt.ylabel(r'$\rho$ [red], P [black], $V_{\rm x}$ [green]')
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend()
plt.subplot(223)
plt.plot(D.x1,D.vx1,color='g',linewidth=1.2,linestyle="-.",label="velocity_x1")
plt.xlabel(r'x')
plt.ylabel(r'$\rho$ [red], P [black], $V_{\rm x}$ [green]')
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend()
plt.subplot(224)
plt.plot(D.x1,D.rho,color='r',linewidth=1.2,linestyle="-",label="density")
plt.plot(D.x1,D.prs,color='k',linewidth=1.2,linestyle="--",label="pressure")
plt.plot(D.x1,D.vx1,color='g',linewidth=1.2,linestyle="-.",label="velocity_x1")
plt.xlabel(r'x')
plt.ylabel(r'$\rho$ [red], P [black], $V_{\rm x}$ [green]')
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend()
plt.savefig('sod_1.pdf',dpi=80)
plt.tight_layout()#调整整体空白 避免出现重叠
plt.subplots_adjust(wspace=0.2,hspace=0.3)

# %%
plt.figure(figsize=(8,5))
plt.plot(D.x1,D.rho,color='r',linewidth=1.2,linestyle="-",label="density")
plt.plot(D.x1,D.prs,color='k',linewidth=1.2,linestyle="--",label="pressure")
plt.plot(D.x1,D.vx1,color='g',linewidth=1.2,linestyle="-.",label="velocity_x1")         
plt.xlabel(r'x')
plt.ylabel(r'$\rho$ [red], P [black], $V_{\rm x}$ [green]')
plt.title(r'Sod shock Tube test')
# 设置x轴和y轴范围
plt.xlim(0.0, 1.0)
plt.ylim(-0.2, 1.2)
# 设置x轴下标和y轴下标
plt.xticks(np.linspace(0, 1, 11, endpoint=True))
plt.yticks(np.linspace(-0.2, 1.2, 8, endpoint=True))
plt.legend(loc="center left",frameon=False)#loc是图例位置  frameon是图例
plt.savefig('sod_2.pdf',dpi=80)

# %%
type(D.rho)
# Out:
# numpy.ndarray

# %%
D.rho.size
# Out:
# 400

# %%
D.rho.shape
# Out:
# (400,)

# %%
D.rho.ndim
# Out:
# 1

# %%
len(D.rho)
# Out:
# 400

# %%
DT=D.rho.reshape(400,1)
type(DT)
# Out:
# numpy.ndarray

# %%
DT.shape
# Out:
# (400, 1)

# %%
DT=np.transpose(DT)
DT.shape
# Out:
# (1, 400)

# %%
type(D) #D还不是np的数据 但是D.xxx是np的数据 可以化出来用
# Out:
# pyPLUTO.pload

# %%
A=np.array([1,2,3]).reshape((3,1))
A.shape
#行前列后
# Out:
# (3, 1)

# %%
A
# Out:
# array([1, 2, 3])

# %%
B=np.array([4,5,6]).reshape((3,1))
B.shape
# Out:
# (3, 1)

# %%
C=np.concatenate((A,B),axis=1)
C.shape
# Out:
# (3, 2)

# %%
data = pd.DataFrame(C,columns=["rho","prs"])
data.head()
# Out:
#    rho  prs
# 0    1    4
# 1    2    5
# 2    3    6

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([.1, .1, .8, .8])


ax.plot(D.x1,D.rho,color='r',linewidth=1.2,linestyle="-",label="density")
plt.xlabel(r'x')
plt.ylabel(r'$\rho$ [red], P [black], $V_{\rm x}$ [green]')
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend(loc="center left",frameon=False)
#嵌套图1
inner_ax1 = fig.add_axes([.18, .18, .25, .25])
inner_ax1.plot(D.x1,D.prs,color='k',linewidth=1.2,linestyle="--",label="pressure")
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend(loc="upper right",frameon=False,markerscale=0.2,fontsize=8)
#markerscale是图例标记与原始标记的相对大小
#fontsize是字体大小
#嵌套图
inner_ax2 = fig.add_axes([.6, .6, .25, .25])
inner_ax2.plot(D.x1,D.vx1,color='g',linewidth=1.2,linestyle="-.",label="velocity_x1")
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend(loc="upper left",frameon=False,markerscale=0.2,fontsize=8)

plt.savefig('sod_3.pdf',dpi=80)

# %%
with sns.axes_style("darkgrid"): #临时设置背景
    plt.figure(figsize=(8,5))
    plt.plot(D.x1,D.rho,color='r',linewidth=1.2,linestyle="-",label="density")
    plt.plot(D.x1,D.prs,color='k',linewidth=1.2,linestyle="--",label="pressure")
    plt.plot(D.x1,D.vx1,color='g',linewidth=1.2,linestyle="-.",label="velocity_x1")         
    plt.xlabel(r'x')
    plt.ylabel(r'$\rho$ [red], P [black], $V_{\rm x}$ [green]')
    plt.title(r'Sod shock Tube test')
    plt.axis([0.0,1.0,-0.2,1.2])
    plt.legend(loc="center left",frameon=False)
    plt.savefig('sod_4.pdf',dpi=80)

# %%
sns.set(style="darkgrid")
#因为D不是pandas的DF类型 所以无法直接用seaborn画 需要转化
x1change=D.x1.reshape((len(D.x1),1))
rhochange=D.rho.reshape((len(D.rho),1))#要预先知道D.rho的形状 再reshape不太方便 用len和size都可以
prschange=D.prs.reshape((D.prs.size,1))#
x1change.shape
rhochange.shape
#data_rhoprs = pd.DataFrame(np.random.randint(0,20,(10,2)),columns=['rho','prs'])#index can be seen as grid id
# Out:
# (400, 1)

# %%
prschange.shape
# Out:
# (400, 1)

# %%
rpsum=np.concatenate((x1change,rhochange,prschange),axis=1)
rpsum.shape
# Out:
# (400, 3)

# %%
datarp = pd.DataFrame(rpsum,columns=["x1","rho","prs"])
datarp.head()
# Out:
#         x1  rho  prs
# 0  0.00125  1.0  1.0
# 1  0.00375  1.0  1.0
# 2  0.00625  1.0  1.0
# 3  0.00875  1.0  1.0
# 4  0.01125  1.0  1.0

# %%
sns.distplot(datarp['rho'])

# %%
sns.distplot(datarp['prs'])

# %%
sns.distplot(datarp['rho'],kde=False,rug=True)

# %%
sns.kdeplot(datarp['rho'],shade=True)

# %%
sns.jointplot(x='rho',y='prs',kind='reg',data=datarp)

# %%
sns.jointplot(x='rho',y='prs',kind='hex',data=datarp)

# %%
sns.jointplot(x='rho',y='prs',kind='kde',data=datarp)

# %%
plt.plot(datarp['x1'],datarp['rho'])

# %%
plt.figure(num=1,figsize=(8,5))#定义编号为1 大小为(8,5)
plt.plot(datarp['x1'],datarp['rho'],color='red',linewidth=2,linestyle='--')

# %%
plt.figure(num=1,figsize=(8,5))#定义编号为1 大小为(8,5)
plt.plot(datarp['x1'],datarp['rho'],color='red',linewidth=2,linestyle='--',label="seaborn density")
plt.xlabel(r'x')
plt.ylabel(r'$\rho$')
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend(loc="upper right",frameon=False)
plt.savefig('sod_5.pdf',dpi=80)

# %%
plt.figure(figsize=(16,5))#定义编号为1 大小为(8,5)
plt.subplot(121) 
plt.plot(datarp['x1'],datarp['rho'],color='red',linewidth=2,linestyle='--',label="seaborn density")
plt.xlabel(r'x')
plt.ylabel(r'$\rho$') #rho转为希腊字母才要$和latex一样 下面的prs就不需要 不然会报错
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend(loc="upper right",frameon=False)


plt.subplot(122) 
plt.plot(datarp['x1'],datarp['prs'],color='black',linewidth=2,linestyle='--',label="seaborn pressure")
plt.xlabel(r'x')
plt.ylabel(r'prs')
plt.title(r'Sod shock Tube test')
plt.axis([0.0,1.0,-0.2,1.2])
plt.legend(loc="upper right",frameon=False)

plt.savefig('sod_6.pdf',dpi=80)

# %%
sns.pairplot(datarp)

# %%
sns.regplot(x="rho", y="prs",data=datarp)

# %%
sns.lmplot(x="rho", y="prs", data=datarp, x_jitter=.05)

# %%
sns.relplot(x="rho", y="prs", data=datarp);
#relplot集成了散点和线图 可通过参数kind控制
#scatterplot() (with kind="scatter"; the default) lineplot() (with kind="line")

# %%
sns.relplot(x="x1", y="rho", kind="line", data=datarp)
#画这些就直接mat画 没有必要用seaborn

# %%
sns.jointplot(x='rho',y='prs',data=datarp)

# %%
sns.jointplot(x="rho", y="prs", kind="hex", color="k",data=datarp);

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(datarp.rho, datarp.prs, ax=ax)
sns.rugplot(datarp["rho"], color="g", ax=ax)
sns.rugplot(datarp["prs"], vertical=True, ax=ax);

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(df.x, df.y, ax=ax)
sns.rugplot(df.x, color="g", ax=ax)
sns.rugplot(df.y, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(datarp["rho"], datarp["prs"], ax=ax)
sns.rugplot(datarp["rho"], color="g", ax=ax)
sns.rugplot(datarp["prs"], vertical=True, ax=ax);

# %%
g = sns.jointplot(x="rho", y="prs", data=datarp, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="x")
g.ax_joint.collections[0].set_alpha(0) #网格
g.set_axis_labels("$X$", "$Y$")

# %%
f, ax = plt.subplots(figsize=(7, 6))
sns.regplot(x="rho", y="prs", data=datarp, ax=ax);

# %%
f, ax = plt.subplots(figsize=(7, 6))
sns.regplot(x="rho", y="rho", data=datarp, ax=ax);

# %%
sns.jointplot(x="rho", y="prs", data=datarp, kind="reg");

# %%
g = sns.PairGrid(datarp, vars=["rho", "prs"])
g.map(plt.scatter);

# %%
g = sns.PairGrid(datarp)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot, lw=2, legend=False);

# %%
g = sns.PairGrid(datarp,vars=["rho", "prs"])
g.map_upper(plt.scatter,s=10);
g.map_lower(plt.scatter,s=10);
g.map_diag(sns.kdeplot, lw=2, legend=False);

# %%
g = sns.PairGrid(datarp,vars=["rho", "prs"])
g.map_diag(sns.kdeplot, lw=1, legend=False); #对角线元素的处理
g.map_offdiag(sns.kdeplot,cmap="Blues_d",n_levels=6)#非对角线元素的处理

# %%
g = sns.PairGrid(datarp)
g.map_diag(plt.hist)
g.map_offdiag(sns.kdeplot,cmap="Blues_d",n_levels=6)

# %%
g = sns.PairGrid(datarp,vars=["rho", "prs"])
g.map_diag(plt.hist) #这里的hist的Y坐标是不会对的 seaborn有强调这一点
g.map_offdiag(sns.kdeplot,cmap="Blues_d",n_levels=6)

# %%
sns.jointplot(x=datarp["rho"],y=datarp["prs"],kind='kde')

# %%
sns.jointplot(x=datarp["rho"],y=datarp["prs"],kind='hex')

# %%
sns.kdeplot(datarp.rho,datarp.prs,shade=True)
#plt.axis([0.0,1.0,-0.2,1.2]) 可以设置坐标

# %%
sns.kdeplot(datarp.rho,datarp.prs,shade=True,cbar=True)

# %%
datarp.plot.hexbin(x="rho",y="prs",gridsize=5)
#内核还是mat的函数

# %%
datarp.plot.hexbin(x="rho",y="prs",gridsize=20,bins="log")

# %%
#上面是1D数据的处理 下面是2D数据的处理
#上面的1D数据data.0001.dbl用完另外放 因为2D也要处理数据 同理dbl.out和grid.out也是
#特别地 要配套grid和dbl.out 因为你如果用single_file和multi_files 那么读数据处理的方式就会不同 所以要谨慎

# %%
D1 = pp.pload(1)
D2 = pp.pload(2) # Loading the data into a pload object D.
# Out:
# Reading Data file : /home/amao/seaborn-data/data.0001.dbl
# Reading Data file : /home/amao/seaborn-data/data.0002.dbl

# %%
f1 = plt.figure(figsize=[8,5])
ax1 = f1.add_subplot(111)
plt.pcolormesh(D1.x1,D1.x2,D1.rho.T)
plt.colorbar()
ax1.set_xlabel(r'x')
ax1.set_ylabel(r'y')
ax1.axis([0,10,0.0,10.0])
ax1.set_aspect('equal')
ax1.set_title(r'density')
plt.savefig('snr_01.png')#不能存为pdf会跑挂

# %%
f1 = plt.figure(figsize=[8,5])
ax1 = f1.add_subplot(111)
plt.pcolormesh(D2.x1,D2.x2,D2.rho.T)
plt.colorbar()
ax1.set_xlabel(r'x')
ax1.set_ylabel(r'y')
ax1.axis([0,10,0.0,10.0])
ax1.set_aspect('equal')
ax1.set_title(r'density')
plt.savefig('snr_02.png')#不能存为pdf会跑挂

# %%
I = pp.Image()
I.pldisplay(D1, D1.rho,x1=D1.x1,x2=D1.x2,label1='x',label2='y',title=r'Density $\rho$ ',cbar=(True,'vertical'),
            figsize=[8,5])
plt.savefig('snr_03.png') # Only to be saved as either .png or .jpg
