# %%
pwd
# Out:
# u'/home/ynu/3d_data'

# %%
cd /home/ynu/3d_data/
# Out:
# /home/ynu/3d_data

# %%
ls
# Out:
# definitions.h  grid.out  mag.py      pyPLUTO.py   rho.py
# density10.png  init.c    pluto.ini*  pyPLUTO.pyc

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyPLUTO as pp
import seaborn as sns
# %matplotlib inline

# %%
plt.rcParams['xtick.direction']='in'
plt.rcParams['ytick.direction']='in'
plt.rcParams['xtick.top']='True'
plt.rcParams['ytick.right']='True'
plt.rcParams['font.size']=14 #字体大小 包括xy轴的字体 colorbar的字体

# %%
D = pp.pload(10) # Loading the data into a pload object D.
#grid.out dbl.out should contain

# %%
type(D.rho.T)
# Out:
# numpy.ndarray

# %%
D.rho.T.size
# Out:
# 16777216

# %%
D.rho.T.shape
# Out:
# (256, 256, 256)

# %%
Drho_xy_slice = D.rho.T[::,0]

# %%
type(Drho_xy_slice)
# Out:
# numpy.ndarray

# %%
Drho_xy_slice.shape
# Out:
# (256, 256)

# %%
Drho_xy_slice.size
# Out:
# 65536

# %%
f1 = plt.figure(figsize=[12,8])
ax1 = f1.add_subplot(111)
plt.pcolormesh(D.x1,D.x2,Drho_xy_slice)
plt.colorbar()
plt.minorticks_on()
ax1.set_xlabel(r'x (pc)')
ax1.set_ylabel(r'y (pc)')
ax1.axis([0,8,0.0,8.0])
ax1.set_aspect('equal')
ax1.set_title(r'density with t=1000 years')
plt.savefig('density10.png')#密度磁场图不能存为pdf会跑很久
